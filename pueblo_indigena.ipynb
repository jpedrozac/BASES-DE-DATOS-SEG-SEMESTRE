# %% [markdown]
# ##**<font color='#BF4AD4'>Cargue de librerias</font>**

# %%
import pandas as pd
from google.colab import files

# %% [markdown]
# ## **<font color='#3498DB'>Cargue del dataframe</font>**

# %%
url = "https://raw.githubusercontent.com/Omaira85/BASES-DE-DATOS-SEG-SEMESTRE/main/Pueblo%20indigena1.csv"
puebloindigena = pd.read_csv(url, sep=';', encoding = 'unicode_escape')
puebloindigena
# Out:
#     Código    Departamento Población total         Maya  Garífuna       Xinka  \
# 0      NaN  Total nacional        14901286      6207503     19529      264167
# 1      1.0       Guatemala       3 015 081      402 376     4 583       3 382
# 2      2.0     El Progreso         176 632        2 627       184          46
# 3      3.0    Sacatepéquez         330 469      132 762       428         206
# 4      4.0   Chimaltenango         615 776      481 335       563         237
# 5      5.0       Escuintla         733 181       37 100       933         259
# 6      6.0      Santa Rosa         396 607        7 863       646      55 855
# 7      7.0          Sololá         421 583      406 295       387          35
# 8      8.0     Totonicapán         418 569      410 195       274          49
# 9      9.0  Quetzaltenango         799 101      406 491       675         206
# 10    10.0   Suchitepéquez         554 695      211 103       639         210
# ...

# %% [markdown]
# ## **<font color='#3498DB'>Limpieza</font>**

# %% [markdown]
# ### **Eliminación de tildes**

# %%
import unicodedata

def strip_accents(s):
  if (type(s) == str):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
  return s




for column in puebloindigena.keys():
  puebloindigena[column] = puebloindigena[column].map(strip_accents)

puebloindigena
# Out:
#     Código    Departamento Población total         Maya  Garífuna       Xinka  \
# 0      NaN  Total nacional        14901286      6207503     19529      264167
# 1      1.0       Guatemala       3 015 081      402 376     4 583       3 382
# 2      2.0     El Progreso         176 632        2 627       184          46
# 3      3.0    Sacatepequez         330 469      132 762       428         206
# 4      4.0   Chimaltenango         615 776      481 335       563         237
# 5      5.0       Escuintla         733 181       37 100       933         259
# 6      6.0      Santa Rosa         396 607        7 863       646      55 855
# 7      7.0          Solola         421 583      406 295       387          35
# 8      8.0     Totonicapan         418 569      410 195       274          49
# 9      9.0  Quetzaltenango         799 101      406 491       675         206
# 10    10.0   Suchitepequez         554 695      211 103       639         210
# ...

# %% [markdown]
# ### **Cambio nombre de columnas**

# %%
puebloindigena.columns = ['CODIGO', 'DEPARTAMENTO', 'POBLACION_TOTAL', 'PDP_MAYA','PDP_GARIFUNA','PDP_XINCA', 'PDP_AFRODESCENDIENTE/CREOLE/AFROMESTIZO', 'PDP_LADINA(O)','PDP_EXTRANJERA(O)' ]

# %%
puebloindigena
# Out:
#     CODIGO    DEPARTAMENTO POBLACION_TOTAL     PDP_MAYA PDP_GARIFUNA  \
# 0      NaN  Total nacional        14901286      6207503        19529
# 1      1.0       Guatemala       3 015 081      402 376        4 583
# 2      2.0     El Progreso         176 632        2 627          184
# 3      3.0    Sacatepequez         330 469      132 762          428
# 4      4.0   Chimaltenango         615 776      481 335          563
# 5      5.0       Escuintla         733 181       37 100          933
# 6      6.0      Santa Rosa         396 607        7 863          646
# 7      7.0          Solola         421 583      406 295          387
# 8      8.0     Totonicapan         418 569      410 195          274
# 9      9.0  Quetzaltenango         799 101      406 491          675
# 10    10.0   Suchitepequez         554 695      211 103          639
# 11    11.0      Retalhuleu         326 828       48 871          258
# 12    12.0      San Marcos       1 032 277      318 093          757
# ...

# %% [markdown]
# ### **Informacion de la base y tipos de variables de cada una de las columnas del Dataframe**

# %%
puebloindigena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CODIGO                                   22 non-null     float64
#  1   DEPARTAMENTO                             23 non-null     object
#  2   POBLACION_TOTAL                          23 non-null     object
#  3   PDP_MAYA                                 23 non-null     object
#  4   PDP_GARIFUNA                             23 non-null     object
#  5   PDP_XINCA                                23 non-null     object
#  6   PDP_AFRODESCENDIENTE/CREOLE/AFROMESTIZO  23 non-null     object
#  7   PDP_LADINA(O)                            23 non-null     object
#  8   PDP_EXTRANJERA(O)                        23 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 1.7+ KB

# %% [markdown]
# ### **Se remplazan espacios en blanco por ningún valor**

# %%
def remover_espacio(cadena):
  return cadena.replace(" ", "", regex = True)

# %%
puebloindigena.iloc[:, 2:9] = remover_espacio(puebloindigena.iloc[:, 2:9])

# %%
puebloindigena
# Out:
#     CODIGO    DEPARTAMENTO POBLACION_TOTAL PDP_MAYA PDP_GARIFUNA PDP_XINCA  \
# 0      NaN  Total nacional        14901286  6207503        19529    264167
# 1      1.0       Guatemala         3015081   402376         4583      3382
# 2      2.0     El Progreso          176632     2627          184        46
# 3      3.0    Sacatepequez          330469   132762          428       206
# 4      4.0   Chimaltenango          615776   481335          563       237
# 5      5.0       Escuintla          733181    37100          933       259
# 6      6.0      Santa Rosa          396607     7863          646     55855
# 7      7.0          Solola          421583   406295          387        35
# 8      8.0     Totonicapan          418569   410195          274        49
# 9      9.0  Quetzaltenango          799101   406491          675       206
# 10    10.0   Suchitepequez          554695   211103          639       210
# ...

# %% [markdown]
# ### **Se cambian tipos de datos de object a int64**

# %%
puebloindigena = puebloindigena.astype({'POBLACION_TOTAL': 'int64', 'PDP_MAYA': 'int64', 'PDP_GARIFUNA': 'int64', 'PDP_XINCA': 'int64', 'PDP_AFRODESCENDIENTE/CREOLE/AFROMESTIZO': 'int64', 'PDP_LADINA(O)': 'int64', 'PDP_EXTRANJERA(O)': 'int64'})

# %% [markdown]
# ### **Informacion de la base y tipos de variables de cada una de las columnas del Dataframe**

# %%
puebloindigena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CODIGO                                   22 non-null     float64
#  1   DEPARTAMENTO                             23 non-null     object
#  2   POBLACION_TOTAL                          23 non-null     int64
#  3   PDP_MAYA                                 23 non-null     int64
#  4   PDP_GARIFUNA                             23 non-null     int64
#  5   PDP_XINCA                                23 non-null     int64
#  6   PDP_AFRODESCENDIENTE/CREOLE/AFROMESTIZO  23 non-null     int64
#  7   PDP_LADINA(O)                            23 non-null     int64
#  8   PDP_EXTRANJERA(O)                        23 non-null     int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 1.7+ KB

# %%
puebloindigena
# Out:
#     CODIGO    DEPARTAMENTO  POBLACION_TOTAL  PDP_MAYA  PDP_GARIFUNA  \
# 0      NaN  Total nacional         14901286   6207503         19529
# 1      1.0       Guatemala          3015081    402376          4583
# 2      2.0     El Progreso           176632      2627           184
# 3      3.0    Sacatepequez           330469    132762           428
# 4      4.0   Chimaltenango           615776    481335           563
# 5      5.0       Escuintla           733181     37100           933
# 6      6.0      Santa Rosa           396607      7863           646
# 7      7.0          Solola           421583    406295           387
# 8      8.0     Totonicapan           418569    410195           274
# 9      9.0  Quetzaltenango           799101    406491           675
# 10    10.0   Suchitepequez           554695    211103           639
# 11    11.0      Retalhuleu           326828     48871           258
# 12    12.0      San Marcos          1032277    318093           757
# ...

# %%
puebloindigena.to_csv('puebloindigena1.csv')
files.download('puebloindigena1.csv')
